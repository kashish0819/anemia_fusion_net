# %%
import torch
import torch.nn as nn

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
class GeoModel(nn.Module):

    def __init__(self):

        super().__init__()

        self.network = nn.Sequential(

            nn.Linear(1, 8),
            nn.ReLU(),

            nn.Linear(8, 8),
            nn.ReLU()

        )

    def forward(self, x):

        features = self.network(x)

        return features

# %%
model = GeoModel()

print(model)
# Out:
# GeoModel(
#   (network): Sequential(
#     (0): Linear(in_features=1, out_features=8, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=8, bias=True)
#     (3): ReLU()
#   )
# )

# %%
total_params = sum(p.numel() for p in model.parameters())

trainable_params = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print("="*60)
print("Total Parameters     :", total_params)
print("Trainable Parameters :", trainable_params)
print("="*60)
# Out:
# ...
# Total Parameters     : 88
# Trainable Parameters : 88
# ...

# %%
geo = torch.randint(0, 2, (8,1)).float()

geo
# Out:
# tensor([[0.],
#         [1.],
#         [1.],
#         [1.],
#         [0.],
#         [1.],
#         [0.],
#         [0.]])

# %%
features = model(geo)

# %%
print("="*60)
print("Geo Feature Model")
print("="*60)

print("Input Shape :", geo.shape)
print("Output Shape:", features.shape)
# Out:
# ...
# Geo Feature Model
# ...
# Input Shape : torch.Size([8, 1])
# Output Shape: torch.Size([8, 8])

# %%
features
# Out:
# tensor([[0.1811, 0.0424, 0.0000, 0.0000, 0.1691, 0.0000, 0.0236, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0713, 0.0000, 0.0274, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0713, 0.0000, 0.0274, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0713, 0.0000, 0.0274, 0.0000, 0.0000],
#         [0.1811, 0.0424, 0.0000, 0.0000, 0.1691, 0.0000, 0.0236, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0713, 0.0000, 0.0274, 0.0000, 0.0000],
#         [0.1811, 0.0424, 0.0000, 0.0000, 0.1691, 0.0000, 0.0236, 0.0000],
#         [0.1811, 0.0424, 0.0000, 0.0000, 0.1691, 0.0000, 0.0236, 0.0000]],
#        grad_fn=<ReluBackward0>)

# %%
print("="*60)
print("Notebook 08 Completed Successfully")
print("="*60)

print("✔ Input Feature : Country")
print("✔ Geo Encoding  : India=0, Italy=1")
print("✔ Output Vector : 8 Dimensions")
print("✔ Ready for Fusion Network")
# Out:
# ...
# Notebook 08 Completed Successfully
# ...
# ✔ Input Feature : Country
# ✔ Geo Encoding  : India=0, Italy=1
# ✔ Output Vector : 8 Dimensions
# ✔ Ready for Fusion Network
